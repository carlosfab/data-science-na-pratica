# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Mapas
#
# Em muitos casos, é interessante que possamos utilizar mapas para representar nossos dados. A depender do escopo e objetivo do nosso projeto, eles serão primordiais. Portanto, conhecer algumas alternativas para plotar esse tipo de dado é muito importante!
#
# <center><img src="https://i.imgur.com/M3toZK8.png"width="450px"></center>
#
# Uma das possibilidades é a biblioteca [PyDeck](https://deckgl.readthedocs.io/en/latest/). Essa biblioteca é extremamente poderosa, e nos possibilita plotar gráficos muito impressionantes. Essa biblioteca é focada em mapas e faz um excelente trabalho no que se propões a fazer.
#
# <center><img src="https://miro.medium.com/max/3504/1*ms3kXnMX0IJjSYocKxbwHw.png"width="450px"></center>
#
# A outra possibilidade é o [Folium](http://python-visualization.github.io/folium/). Essa também é uma possibilidade interessante, que nos possibilita plotar mapas extremamente interessantes, e entregar um trabalho muito bacana no que diz respeito a mapas.
#
# Mas vamos ver na prática como plotar esses mapas.

# %%
# importando as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# Para esse projeto, utilizaremos um conjunto de dados do portal [Inside Airbnb](http://insideairbnb.com) com dados da cidade de Nova Iorque.
#
# Dentro desse portal, você também pode encontrar conjuntos de dados de outras cidades, para plotar diferentes mapas.

# %%
# importando os dados
df = pd.read_csv("http://data.insideairbnb.com/united-states/ny/new-york-city/2023-03-06/visualisations/listings.csv")
# Out:
# <ipython-input-5-97f6cef03528>:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("http://data.insideairbnb.com/united-states/ny/new-york-city/2023-03-06/visualisations/listings.csv")

# %% [markdown]
# Esse conjunto é muito grande, e para os propósitos dessa aula, isso seria um problema. Para que o mapa fique mais focado, nossa visualização melhor e mais informativa, irei utilizar apenas uma fração do conjunto de dados.
#
# Isso também irá melhorar a performance do nosso mapa interativo.

# %%
# verificando o tamanho do dataset
print('Dataset original: ', df.shape)

# criando um dataset menor
df_map = df.sample(frac=0.01, random_state=0)

# verificando o tamanho do dataset
print('Dataset para o plot: ', df_map.shape)
# Out:
# Dataset original:  (42931, 18)
# Dataset para o plot:  (429, 18)

# %% [markdown]
# Para plotar o nosso mapa, vamos precisar extrair os valores de algumas colunas e transformar em variáveis, para passarmos como parâmetro para o nosso mapa.
#
# Essas variáveis são `latitude`, `longitude` e os labels que queremos mostrar quando passarmos o mouse por. cima dos pontos, que nesse caso serão a descrição dos anúncios, salvos na coluna `name`.
#
# Com essas variáveis estaremos prontos para criar nosso mapa!

# %%
# criando as variáveis necessárias
latitude = df_map.latitude.values
longitude = df_map.longitude.values
listings = df_map.name.values

# %% [markdown]
# Para criar o mapa, primeiro precisamos saber a localidade de onde o nosso mapa irá começar. Para isso, utilizaremos o [Google Maps](https://www.google.com/maps).
#
# Na barra de pesquisa, busque pela cidade que está analisando, no nosso caso, Nova Iorque. Ao visualizar o mapa, iremos buscar as informações de latitude, longigute e o zoom inicial no endereço do browser.
#
# Clique na barra de endereço, e encontre esses 3 parâmetros, que estarão juntos, em sequência.
#
# Pronto, você já tem o seu mapa base!

# %%
# criando o mapa
nyc = folium.Map(location=[40.7267795,-73.8828923],
                 zoom_start=10)
nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f73a5763d1b55a42d0b293d6d314eaba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f73a5763d1b55a42d0b293d6d314eaba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f73a5763d1b55a42d0b293d6d314eaba = L.map(
#                 &quot;map_f73a5763d1b55a42d0b293d6d314eaba&quot;,
#                 {
#                     center: [40.7267795, -73.8828923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db670f66ee9d83b4c0ac296021de0595 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Com nosso mapa interativo plotado, nós podemos também adicionar nossos markers, que são os anúncios.
#
# Eles serão plotados como marcadores em suas respectivas localidades, com suas descrições sendo exibidas ao passarmos o mouse por cima deles.
#
# Para isso, vamos criar uma função, que percorre nossos pontos e os adiciona ao mapa.

# %%
# adicionando os marcadores
for lat, lon, listing in zip(latitude, longitude, listings):
    folium.Marker(location=[float(lat), float(lon)], popup=listing).add_to(nyc)
# plotando o mapa
nyc.save('nyc_map.html')
nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f73a5763d1b55a42d0b293d6d314eaba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f73a5763d1b55a42d0b293d6d314eaba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f73a5763d1b55a42d0b293d6d314eaba = L.map(
#                 &quot;map_f73a5763d1b55a42d0b293d6d314eaba&quot;,
#                 {
#                     center: [40.7267795, -73.8828923],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db670f66ee9d83b4c0ac296021de0595 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#             var marker_8dd44d9b52044c790b36fced95309371 = L.marker(
#                 [40.76577, -73.98375],
#                 {}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#         var popup_7284fccfd6d6bdd89df0cf73d6b1ec20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5d68fcc412e4d8568757c03b0cc6dc3 = $(`&lt;div id=&quot;html_f5d68fcc412e4d8568757c03b0cc6dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fully Furnished 2BR Apartment in Midtown Manhattan&lt;/div&gt;`)[0];
#                 popup_7284fccfd6d6bdd89df0cf73d6b1ec20.setContent(html_f5d68fcc412e4d8568757c03b0cc6dc3);
#
#
#
#         marker_8dd44d9b52044c790b36fced95309371.bindPopup(popup_7284fccfd6d6bdd89df0cf73d6b1ec20)
#         ;
#
#
#
#
#             var marker_94b3f4e93aa954aaa0981a03034a8696 = L.marker(
#                 [40.76196, -73.91701],
#                 {}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#         var popup_c13e33d511d8494731817c855413916d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c72c74104ec4e255887603c301ce21c9 = $(`&lt;div id=&quot;html_c72c74104ec4e255887603c301ce21c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Best town in Queens : Reasonable long term stay&lt;/div&gt;`)[0];
#                 popup_c13e33d511d8494731817c855413916d.setContent(html_c72c74104ec4e255887603c301ce21c9);
#
#
#
#         marker_94b3f4e93aa954aaa0981a03034a8696.bindPopup(popup_c13e33d511d8494731817c855413916d)
#         ;
#
#
#
#
#             var marker_4bdf0dc52309e8b79cd0cb0d8b735b7f = L.marker(
#                 [40.68362, -73.99381],
#                 {}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#         var popup_480c40ef5527c1973641d8dcf7c2adc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_441b1e7abc46a0d46b46c14bced4b84f = $(`&lt;div id=&quot;html_441b1e7abc46a0d46b46c14bced4b84f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lovely apartment in Brooklyn.&lt;/div&gt;`)[0];
#                 popup_480c40ef5527c1973641d8dcf7c2adc0.setContent(html_441b1e7abc46a0d46b46c14bced4b84f);
#
#
#
#         marker_4bdf0dc52309e8b79cd0cb0d8b735b7f.bindPopup(popup_480c40ef5527c1973641d8dcf7c2adc0)
#         ;
#
#
#
#
#             var marker_e55c8aca9bb1695aaec1c74153e9c5e1 = L.marker(
#                 [40.68544, -73.84474],
#                 {}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#         var popup_92f73d7fe1fac0720b19dc5869b12bba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d43e53f4280e8a8c60fb2494a486b9e2 = $(`&lt;div id=&quot;html_d43e53f4280e8a8c60fb2494a486b9e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LOCATION ,LOCATION, LOCATION. Close to all&lt;/div&gt;`)[0];
#                 popup_92f73d7fe1fac0720b19dc5869b12bba.setContent(html_d43e53f4280e8a8c60fb2494a486b9e2);
#
#
#
#         marker_e55c8aca9bb1695aaec1c74153e9c5e1.bindPopup(popup_92f73d7fe1fac0720b19dc5869b12bba)
#         ;
#
#
#
#
#             var marker_61e40fcac9a5dd7ee754b1ecb517aa00 = L.marker(
#                 [40.74077, -73.89327],
#                 {}
#             ).addTo(map_f73a5763d1b55a42d0b293d6d314eaba);
#
#
#         var popup_52a3bbf76bbb8897a6b4243d78e4583a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98f44a5500e2ce00780c9ca2fe5d5f04 = $(`&lt;div id=&quot;html_98f44a5500e2ce00780c9ca2fe5d5f04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cozy Room&amp; Area in Queens♪&lt;/div&gt;`)[0];
#                 popup_52a3bbf76bbb8897a6b4243d78e4583a.setContent(html_98f44a5500e2ce00780c9ca2fe5d5f04);
#
#
#
#         marker_61e40fcac9a5dd7ee754b1ecb517aa00.bindPopup(popup_52a3bbf76bbb8897a6b4243d78e4583a)
#         ;

# %% [markdown]
# Além disso, podemos também facilmente salvar nosso mapa finalizado como um artigo html, para ser aproveitado de outras formas.
#
# Também é possível salvar como json.

# %%
# salvando
nyc.save('nyc_map.html')

# %%
pip install pydeck -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 38.6 MB/s eta 0:00:00

# %%
#mapanyc
# código de exemplo do PyDeck
import pydeck as pdk

# criando a camada
layer = pdk.Layer(
    'HexagonLayer',  # `type` positional argument is here
    df_map,
    get_position=['longitude', 'latitude'],
    auto_highlight=True,
    elevation_scale=50,
    pickable=True,
    elevation_range=[0, 3000],
    extruded=True,
    coverage=1)

# definindo a visão
view_state = pdk.ViewState(
    longitude=-73.8828923,
    latitude=40.7267795,
    zoom=6,
    min_zoom=5,
    max_zoom=15,
    pitch=40.5,
    bearing=-27.36)

# combinando os dois em um deck, e visualizando
r = pdk.Deck(layers=[layer], initial_view_state=view_state)

# salvando como html
r.to_html('hexagon-example.html')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <title>pydeck</title>
#         <script src="https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js"></script>
#         <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css" />
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css" />
#     <script src='https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js'></script>
#     <style>
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     </style>
#   </head>
#   <body>
#     <div id="deck-container">
#     </div>
#   </body>
#   <script>
#     const container = document.getElementById('deck-container');
#     const jsonInput = {
#   "initialViewState": {
#     "bearing": -27.36,
#     "latitude": 40.7267795,
#     "longitude": -73.8828923,
#     "maxZoom": 15,
#     "minZoom": 5,
#     "pitch": 40.5,
#     "zoom": 6
#   },
#   "layers": [
#     {
#       "@@type": "HexagonLayer",
#       "autoHighlight": true,
#       "coverage": 1,
#       "data": [
#         {
#           "availability_365": 270,
#           "calculated_host_listings_count": 88,
#           "host_id": 2867137,
#           "host_name": "Avi",
#           "id": 52189570,
#           "last_review": "2022-12-04",
#           "latitude": 40.76577,
#           "license": NaN,
#           "longitude": -73.98375,
#           "minimum_nights": 30,
#           "name": "Fully Furnished 2BR Apartment in Midtown Manhattan",
#           "neighbourhood": "Hell's Kitchen",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 3,
#           "number_of_reviews_ltm": 2,
#           "price": 165,
#           "reviews_per_month": 0.23,
#           "room_type": "Entire home/apt"
#         },
#         {
#           "availability_365": 17,
#           "calculated_host_listings_count": 178,
#           "host_id": 204704622,
#           "host_name": "Momoyo",
#           "id": 43053652,
#           "last_review": "2021-11-18",
#           "latitude": 40.76196,
#           "license": NaN,
#           "longitude": -73.91701,
#           "minimum_nights": 30,
#           "name": "Best town in Queens : Reasonable long term stay",
#           "neighbourhood": "Astoria",
#           "neighbourhood_group": "Queens",
#           "number_of_reviews": 3,
#           "number_of_reviews_ltm": 0,
#           "price": 39,
#           "reviews_per_month": 0.1,
#           "room_type": "Private room"
#         },
#         {
#           "availability_365": 0,
#           "calculated_host_listings_count": 1,
#           "host_id": 87988,
#           "host_name": "Samantha",
#           "id": 20173894,
#           "last_review": "2018-08-24",
#           "latitude": 40.68362,
#           "license": NaN,
#           "longitude": -73.99381,
#           "minimum_nights": 30,
#           "name": "Lovely apartment in Brooklyn.",
#           "neighbourhood": "Carroll Gardens",
#           "neighbourhood_group": "Brooklyn",
#           "number_of_reviews": 2,
#           "number_of_reviews_ltm": 0,
#           "price": 125,
#           "reviews_per_month": 0.03,
#           "room_type": "Entire home/apt"
#         },
#         {
#           "availability_365": 113,
#           "calculated_host_listings_count": 2,
#           "host_id": 151421618,
#           "host_name": "Adesh",
#           "id": 49811796,
#           "last_review": "2022-05-04",
#           "latitude": 40.68544,
#           "license": NaN,
#           "longitude": -73.84474,
#           "minimum_nights": 30,
#           "name": "LOCATION ,LOCATION, LOCATION. Close to all",
#           "neighbourhood": "Ozone Park",
#           "neighbourhood_group": "Queens",
#           "number_of_reviews": 6,
#           "number_of_reviews_ltm": 1,
#           "price": 78,
#           "reviews_per_month": 0.3,
#           "room_type": "Entire home/apt"
#         },
#         {
#           "availability_365": 0,
#           "calculated_host_listings_count": 192,
#           "host_id": 200239515,
#           "host_name": "Shogo",
#           "id": 35236534,
#           "last_review": "2020-03-18",
#           "latitude": 40.74077,
#           "license": NaN,
#           "longitude": -73.89327,
#           "minimum_nights": 30,
#           "name": "Cozy Room& Area in Queens\u266a",
#           "neighbourhood": "Woodside",
#           "neighbourhood_group": "Queens",
#           "number_of_reviews": 2,
#           "number_of_reviews_ltm": 0,
#           "price": 40,
#           "reviews_per_month": 0.05,
#           "room_type": "Private room"
#         },
#         {
#           "availability_365": 42,
#           "calculated_host_listings_count": 1,
#           "host_id": 95999344,
#           "host_name": "Marie L",
#           "id": 20325974,
#           "last_review": "2023-02-26",
#           "latitude": 40.72719,
#           "license": NaN,
#           "longitude": -73.97775,
#           "minimum_nights": 2,
#           "name": "Manhattan East Village, lower East Side",
#           "neighbourhood": "East Village",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 282,
#           "number_of_reviews_ltm": 62,
#           "price": 200,
#           "reviews_per_month": 4.24,
#           "room_type": "Entire home/apt"
#         },
#         {
#           "availability_365": 88,
#           "calculated_host_listings_count": 1,
#           "host_id": 14875796,
#           "host_name": "Maria",
#           "id": 53425829,
#           "last_review": "2022-10-10",
#           "latitude": 40.71262,
#           "license": NaN,
#           "longitude": -73.98991,
#           "minimum_nights": 12,
#           "name": "Private room in vibrant Lower East Side",
#           "neighbourhood": "Lower East Side",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 5,
#           "number_of_reviews_ltm": 5,
#           "price": 120,
#           "reviews_per_month": 0.65,
#           "room_type": "Private room"
#         },
#         {
#           "availability_365": 158,
#           "calculated_host_listings_count": 107,
#           "host_id": 25138314,
#           "host_name": "RoomPicks By Antony",
#           "id": 772502029842228959,
#           "last_review": NaN,
#           "latitude": 40.74838,
#           "license": NaN,
#           "longitude": -73.98726,
#           "minimum_nights": 1,
#           "name": "Stay in the Heart of NYC! Steps to Empire State!",
#           "neighbourhood": "Midtown",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 0,
#           "number_of_reviews_ltm": 0,
#           "price": 388,
#           "reviews_per_month": NaN,
#           "room_type": "Private room"
#         },
#         {
#           "availability_365": 351,
#           "calculated_host_listings_count": 159,
#           "host_id": 162280872,
#           "host_name": "Urban Furnished",
#           "id": 43909885,
#           "last_review": "2023-01-10",
#           "latitude": 40.73843,
#           "license": NaN,
#           "longitude": -73.97987,
#           "minimum_nights": 30,
#           "name": "24-5  Furnished Studio W/D Prime Gramercy",
#           "neighbourhood": "Kips Bay",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 5,
#           "number_of_reviews_ltm": 4,
#           "price": 140,
#           "reviews_per_month": 0.21,
#           "room_type": "Entire home/apt"
#         },
#         {
#           "availability_365": 65,
#           "calculated_host_listings_count": 1,
#           "host_id": 45625618,
#           "host_name": "Empressive Stays",
#           "id": 52850559,
#           "last_review": "2022-11-02",
#           "latitude": 40.79678,
#           "license": NaN,
#           "longitude": -73.93379,
#           "minimum_nights": 5,
#           "name": "EAST HARLEM PRIVATE APARTMENT- near mall and trans",
#           "neighbourhood": "East Harlem",
#           "neighbourhood_group": "Manhattan",
#           "number_of_reviews": 6,
#           "number_of_reviews_ltm": 4,
#           "price": 97,
#           "reviews_per_month": 0.41,

# %%
# código de exemplo do PyDeck
import pydeck as pdk

UK_ACCIDENTS_DATA = 'https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/3d-heatmap/heatmap-data.csv'

layer = pdk.Layer(
    'HexagonLayer',  # `type` positional argument is here
    UK_ACCIDENTS_DATA,
    get_position=['lng', 'lat'],
    auto_highlight=True,
    elevation_scale=50,
    pickable=True,
    elevation_range=[0, 3000],
    extruded=True,
    coverage=1)

# Set the viewport location
view_state = pdk.ViewState(
    longitude=-1.415,
    latitude=52.2323,
    zoom=6,
    min_zoom=5,
    max_zoom=15,
    pitch=40.5,
    bearing=-27.36)

# Combined all of it and render a viewport
r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.to_html('hexagon-example.html')
